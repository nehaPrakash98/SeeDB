# %% [markdown]
# Contributor : Chirag Uday Kamath(cukamath@umass.edu)

# %% [markdown]
# # Top K=10 recommended views on running SeeDb Algorithm on DBLP Dataset for 4 difference distance measures

# %% [markdown]
# KL Divergence

# %%
# %run main_dblp kl_divergence
# Out:
# You are connected to -  ('PostgreSQL 14.2, compiled by Visual C++ build 1914, 64-bit',)
#
# Generating aggregate queries
# Total aggregate views: 30
# {'year': {'pages': {'min', 'count', 'avg', 'max', 'sum'}, 'coauthors': {'min', 'count', 'avg', 'max', 'sum'}}}
# Visualizing year v/s min(pages)
# Visualizing year v/s count(pages)
# Visualizing year v/s avg(pages)
# Visualizing year v/s max(pages)
# Visualizing year v/s sum(pages)
# Visualizing year v/s min(coauthors)
# Visualizing year v/s count(coauthors)
# Visualizing year v/s avg(coauthors)
# Visualizing year v/s max(coauthors)
# Visualizing year v/s sum(coauthors)
# PostgreSQL connection is closed
# LATENCY TABLE :
# +---------------+----------------------+---------------------+----------------------+---------------------+---------------------+---------------------+
# | Operations    | phase1               | phase2              | phase3               | phase4              | phase5              | total_time          |
# ...

# %% [markdown]
# Earth Movers Distance

# %%
# %run main_dblp emd_distance
# Out:
# You are connected to -  ('PostgreSQL 14.2, compiled by Visual C++ build 1914, 64-bit',)
#
# Generating aggregate queries
# Total aggregate views: 30
# {'venue': {'pages': {'min', 'count', 'avg', 'max', 'sum'}, 'coauthors': {'min', 'count', 'avg', 'max', 'sum'}}}
# Visualizing venue v/s min(pages)
# Visualizing venue v/s count(pages)
# Visualizing venue v/s avg(pages)
# Visualizing venue v/s max(pages)
# Visualizing venue v/s sum(pages)
# Visualizing venue v/s min(coauthors)
# Visualizing venue v/s count(coauthors)
# Visualizing venue v/s avg(coauthors)
# Visualizing venue v/s max(coauthors)
# Visualizing venue v/s sum(coauthors)
# PostgreSQL connection is closed
# LATENCY TABLE :
# +---------------+---------------------+----------------------+---------------------+---------------------+-----------------------+-----------------------+
# ...

# %% [markdown]
# JS Divergence

# %%
# %run main_dblp js_divergence_distance
# Out:
# You are connected to -  ('PostgreSQL 14.2, compiled by Visual C++ build 1914, 64-bit',)
#
# Generating aggregate queries
# Total aggregate views: 30
# {'year': {'pages': {'min', 'count', 'avg', 'max', 'sum'}, 'coauthors': {'min', 'count', 'avg', 'max', 'sum'}}}
# Visualizing year v/s min(pages)
# Visualizing year v/s count(pages)
# Visualizing year v/s avg(pages)
# Visualizing year v/s max(pages)
# Visualizing year v/s sum(pages)
# Visualizing year v/s min(coauthors)
# Visualizing year v/s count(coauthors)
# Visualizing year v/s avg(coauthors)
# Visualizing year v/s max(coauthors)
# Visualizing year v/s sum(coauthors)
# PostgreSQL connection is closed
# LATENCY TABLE :
# +---------------+---------------------+---------------------+----------------------+---------------------+-----------------------+-----------------------+
# | Operations    | phase1              | phase2              | phase3               | phase4              | phase5                | total_time            |
# ...

# %% [markdown]
# Euclidean Distance

# %%
# %run main_dblp euclidean_distance
# Out:
# You are connected to -  ('PostgreSQL 14.2, compiled by Visual C++ build 1914, 64-bit',)
#
# Generating aggregate queries
# Total aggregate views: 30
# {'year': {'pages': {'min', 'count', 'sum'}, 'coauthors': {'count', 'avg', 'max', 'sum'}}, 'venue': {'pages': {'count', 'max'}, 'coauthors': {'count'}}}
# Visualizing year v/s min(pages)
# Visualizing year v/s count(pages)
# Visualizing year v/s sum(pages)
# Visualizing year v/s count(coauthors)
# Visualizing year v/s avg(coauthors)
# Visualizing year v/s max(coauthors)
# Visualizing year v/s sum(coauthors)
# Visualizing venue v/s count(pages)
# Visualizing venue v/s max(pages)
# Visualizing venue v/s count(coauthors)
# PostgreSQL connection is closed
# LATENCY TABLE :
# +---------------+----------------------+----------------------+----------------------+----------------------+---------------------+---------------------+
# ...
