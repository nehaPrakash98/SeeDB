# %% [markdown]
# Contributor : Chirag Uday Kamath(cukamath@umass.edu)

# %% [markdown]
# # Top K=15 recommended views on running SeeDb Algorithm on Census Dataset for 4 difference distance measures

# %% [markdown]
# KL Divergence

# %%
# %run main_census kl_divergence
# Out:
# You are connected to -  ('PostgreSQL 14.2, compiled by Visual C++ build 1914, 64-bit',)
#
# Generating aggregate queries
# Total aggregate views: 200
# {'workclass': {'capital_loss': {'avg'}}, 'relationship': {'capital_loss': {'max'}}, 'native_country': {'capital_gain': {'avg'}, 'capital_loss': {'max', 'avg'}}}
# Visualizing workclass v/s avg(capital_loss)
# Visualizing relationship v/s max(capital_loss)
# Visualizing native_country v/s avg(capital_gain)
# Visualizing native_country v/s max(capital_loss)
# Visualizing native_country v/s avg(capital_loss)
# PostgreSQL connection is closed
# LATENCY TABLE :
# +---------------+---------------------+---------------------+-----------------------+--------------------+-----------------------+----------------------+
# | Operations    | phase1              | phase2              | phase3                | phase4             | phase5                | total_time           |
# ...

# %% [markdown]
# Earth Mover's Distance

# %%
# %run main_census emd_distance
# Out:
# You are connected to -  ('PostgreSQL 14.2, compiled by Visual C++ build 1914, 64-bit',)
#
# Generating aggregate queries
# Total aggregate views: 200
# {'sex': {'capital_loss': {'sum'}, 'hours_per_week': {'sum'}}, 'salary': {'age': {'count'}, 'fnlwgt': {'sum'}, 'hours_per_week': {'sum'}}}
# Visualizing sex v/s sum(capital_loss)
# Visualizing sex v/s sum(hours_per_week)
# Visualizing salary v/s count(age)
# Visualizing salary v/s sum(fnlwgt)
# Visualizing salary v/s sum(hours_per_week)
# PostgreSQL connection is closed
# LATENCY TABLE :
# +---------------+---------------------+---------------------+---------------------+-----------------------+-----------------------+-----------------------+
# | Operations    | phase1              | phase2              | phase3              | phase4                | phase5                | total_time            |
# ...

# %% [markdown]
# JS Divergence

# %%
# %run main_census js_divergence_distance
# Out:
# You are connected to -  ('PostgreSQL 14.2, compiled by Visual C++ build 1914, 64-bit',)
#
# Generating aggregate queries
# Total aggregate views: 200
# {'native_country': {'capital_gain': {'min', 'max', 'avg'}, 'capital_loss': {'max', 'avg'}}}
# Visualizing native_country v/s min(capital_gain)
# Visualizing native_country v/s max(capital_gain)
# Visualizing native_country v/s avg(capital_gain)
# Visualizing native_country v/s max(capital_loss)
# Visualizing native_country v/s avg(capital_loss)
# PostgreSQL connection is closed
# LATENCY TABLE :
# +---------------+--------------------+-----------------------+--------------------+-----------------------+---------------------+----------------------+
# | Operations    | phase1             | phase2                | phase3             | phase4                | phase5              | total_time           |
# ...

# %% [markdown]
# Euclidean Distance

# %%
# %run main_census euclidean_distance
# Out:
# You are connected to -  ('PostgreSQL 14.2, compiled by Visual C++ build 1914, 64-bit',)
#
# Generating aggregate queries
# Total aggregate views: 200
# {'relationship': {'capital_gain': {'max', 'avg'}}, 'native_country': {'capital_gain': {'min'}}, 'salary': {'capital_loss': {'sum'}, 'hours_per_week': {'min'}}}
# Visualizing relationship v/s max(capital_gain)
# Visualizing relationship v/s avg(capital_gain)
# Visualizing native_country v/s min(capital_gain)
# Visualizing salary v/s sum(capital_loss)
# Visualizing salary v/s min(hours_per_week)
# PostgreSQL connection is closed
# LATENCY TABLE :
# +---------------+---------------------+-----------------------+---------------------+-----------------------+---------------------+-----------------------+
# | Operations    | phase1              | phase2                | phase3              | phase4                | phase5              | total_time            |
# ...
